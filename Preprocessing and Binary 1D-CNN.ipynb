# %%
#Import the packages needed for the data preprocessing

import os
import pickle
import numpy as np
from scipy.signal import resample
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt

# %%
#Load the WESAD dataset files
data_path = r'/home/u716716/thesis/wesad data/WESAD'   # Change this to your own path
subjects = ['S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9', 'S10', 'S11', 'S13', 'S14', 'S15', 'S16', 'S17']

df = {}
#Open the data files and add it to a dictionary so that the data is easy to work with
for subject in subjects:
    file_path = os.path.join(data_path, subject, subject + '.pkl')

    with open(file_path, 'rb') as f:
        data = pickle.load(f, encoding = 'latin1')
    df[subject] = data

#A test to see what the form of the data is
print(df['S2']['signal']['wrist']['BVP'].shape)
print(df['S2']['label'].shape)
print(df.keys())
print(df['S2']['signal'].keys())
print(df['S2']['signal']['wrist'].keys())
# Out:
# /tmp/ipykernel_1241461/2834722020.py:10: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   data = pickle.load(f, encoding = 'latin1')
# (389056, 1)
# (4255300,)
# dict_keys(['S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9', 'S10', 'S11', 'S13', 'S14', 'S15', 'S16', 'S17'])
# dict_keys(['chest', 'wrist'])
# dict_keys(['ACC', 'BVP', 'EDA', 'TEMP'])

# %%
#Check to see if GPU is running

import torch

print(f"PyTorch Version: {torch.version.__version__}")
print(f"Is CUDA available? {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"Total GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    print("WARNING: CUDA is not available. You are currently running on the CPU.")
# Out:
# PyTorch Version: 2.5.1+cu121
# Is CUDA available? True
# GPU Name: NVIDIA A40
# Total GPU Memory: 47.62 GB

# %%
#A function to put a filter over the BVP and EDA data, to remove unnecessary noise from the data

def apply_filter(data, signal_type):
    """" 
    Apply signal-specific filtering to physiologicla signals.

    Parameters:
    data: array-like, input physiologicla signal
    signal_type: str, Type of signal ("BVP", "EDA", "TEMP", "ACC")

    Returns: array-like filtered signal
    """

    #Sampling frequencies (Hz) for each physiological signal
    fs_map = {'BVP' : 64, 'EDA': 4, 'TEMP': 4, 'ACC' : 32}
    fs = fs_map.get(signal_type, 64)

    if signal_type == 'BVP':
        #Apply a Butterworth band-pass filter to retain frequencies between 1 and 8 Hz, which corresponds to the useful BVP range
        b, a = butter(4, [1, 8.0], btype = 'band', fs = fs)    
        filtered = filtfilt(b, a, data) 

        #Remove extreme outliers by clipping values outside the 1st and 99th percentiles
        lower = np.percentile(filtered, 1)
        upper = np.percentile(filtered, 99)
        return np.clip(filtered, lower, upper)
        
    
    elif signal_type == 'EDA':
        #Apply a Butterworth low-pass filter with a cutoff frequence of 1 Hz to smooth the EDA signal
        b, a, = butter(4, 1.0, btype = "low", fs = fs)  
        return filtfilt(b, a, data)
    
    #Return the original data for signals without additional filtering
    return data

# %%
#Define the labels for the binary classification task
#Baseline (1) and amusement (3) are grouped as non-stress (0)
#Stress (2) is labelled as stress (1)
BINARY_LABELS = {1: 0, 3: 0, 2:1}

#Labels that will be used in the analysis
VALID_LABELS = [1, 2, 3]

#Select the physiological signal to preprocess
CURRENT_SIGNAL_TYPE = 'EDA'

#Sampling frequencies (Hz) for each signal type
fs_map = {'BVP' : 64, 'ACC' : 32, 'EDA': 4, 'TEMP': 4}
fs = fs_map.get(CURRENT_SIGNAL_TYPE, 64)

processed_data = {}

#Preprocess the data for each subject
for subject in subjects:

    #Load the selected wrist signal
    raw_signal = df[subject]['signal']['wrist'][CURRENT_SIGNAL_TYPE]

    #For ACC, combine the three axes into a single magnitude signal
    if CURRENT_SIGNAL_TYPE == 'ACC':
        signal = np.sqrt(np.sum(np.square(raw_signal), axis=1))
    else:
        signal = raw_signal.flatten()

    #Apply signal-specific filtering
    filtered_signal = apply_filter(signal, CURRENT_SIGNAL_TYPE)

    #Load the labels corresponding to the recording
    labels = df[subject]['label']

    #Downsample the labels to match the signal length
    ratio = len(labels) / len(filtered_signal)
    indices = (np.arange(len(filtered_signal)) * ratio).astype(int)
    labels_ds = labels[indices]

    #Keep only baseline, stress and amusement labels
    mask = np.isin(labels_ds, VALID_LABELS)
    signal_final = filtered_signal[mask]
    labels_final = labels_ds[mask]

    #Create overlapping windows of 60 seconds with a 1-second step size
    window_size = fs * 60
    step_size = fs * 1

    X, y = [], []

    for start in range(0, len(signal_final) - window_size, step_size):
        end = start + window_size
        window_labels = labels_final[start:end]

        #Only keep windows with a single consistent label
        if len(np.unique(window_labels)) == 1:
            label = window_labels[0]

            X.append(signal_final[start:end])
            y.append(BINARY_LABELS[label])

    #Store the processed windows and labels for each subject
    processed_data[subject] = (np.array(X), np.array(y))

#Example output for subject S2
X_test, y_test = processed_data["S2"]

print(f"Processed {CURRENT_SIGNAL_TYPE} for S2")
print(f"Shape: {X_test.shape} | Labels: {np.bincount(y_test)}")
print(f"Subject S2 Windows: {processed_data['S2'][0].shape}")

X_S2, y_S2 = processed_data['S2']

print (f"X shape: {X_S2.shape}")
print(f"Label distribution: {np.bincount(y_S2)}")
# Out:
# Processed EDA for S2
# Shape: (1943, 240) | Labels: [1387  556]
# Subject S2 Windows: (1943, 240)
# X shape: (1943, 240)
# Label distribution: [1387  556]

# %%
#Save the preprocessed data as a pickle file so it can be reused later without repeating the preprocessing steps
file_path = f"processed_{CURRENT_SIGNAL_TYPE}_data.pkl"

with open (file_path, 'wb') as f: 
    pickle.dump(processed_data, f)

#Confirm that the file was successfully created
print(f"Successfully saved {CURRENT_SIGNAL_TYPE} data to {file_path}")
# Out:
# Successfully saved EDA data to processed_EDA_data.pkl

# %%
#Visualize one example baseline window and one example stress window to inspect the shape of the preprocessed data

#Select the first baseline and stress samples from subject S2
baseline_idx = np.where(y_S2 == 0)[0][0]
stress_idx = np.where(y_S2 == 1)[0][0]

plt.figure(figsize=(12,6))

#Plot a baseline window (non-stress)
plt.subplot(2, 1, 1)
plt.plot(X_S2[baseline_idx])
plt.title("Baseline Window (label 0)")

#Plot a stress window
plt.subplot(2, 1, 2)
plt.plot(X_S2[stress_idx])
plt.title("Stress Window (Label 1)")

plt.tight_layout()
plt.show()

# %%
import scipy
def load_and_combine_data():
    """
    Load the preprocessed ACC, BVP, EDA and TEMP data, resample the signals
    to a common length and combine them into a single multimodal dataset.

    For the multimodal dataset without TEMP, remove TEMP from the signals and data
    """

    #Physiological signals that will be combined
    signals = ["ACC", "BVP", "EDA", "TEMP"]

    data_dicts = {}

    #Load the preprocessed pickle files
    for sig in signals:
        filename = f"processed_{sig}_data.pkl"
        print(f"Loading{filename}")
        with open (filename, 'rb') as f:
            data_dicts[sig] = pickle.load(f)
    
    combined_dict = {}

    subjects = data_dicts['BVP'].keys()

    #Common window length used for all signals
    TARGET_LEN = 240

    #Process each subject separately
    for sub in subjects:
        acc_feat, acc_y = data_dicts['ACC'][sub]
        bvp_feat, _ = data_dicts['BVP'][sub]
        eda_feat, _ = data_dicts['EDA'][sub]
        temp_feat, _ = data_dicts['TEMP'][sub]

        #Determine the maximum number of windows available for all signals
        min_windows = min(acc_feat.shape[0], bvp_feat.shape[0],
                          eda_feat.shape[0], temp_feat.shape[0])

        #Resample ACC and BVP to a common length
        acc_resampled = scipy.signal.resample(acc_feat[:min_windows], TARGET_LEN, axis = 1)
        bvp_resampled = scipy.signal.resample(bvp_feat[:min_windows], TARGET_LEN, axis =1)

        #EDA and TEMP already have the desired length and only needs trunction
        eda_resampled = eda_feat[:min_windows]
        temp_resampled = temp_feat[:min_windows]

        #Use the ACC labels as the target labels
        labels = acc_y[:min_windows]

        #Concatenate all signals into a single feature vector
        X_combined = np.concatenate([acc_resampled, bvp_resampled, eda_resampled, temp_resampled], axis=1)

        #Store the combined data for each subject
        combined_dict[sub] = (X_combined, labels)
        print(f"Subject{sub} combined. New feature shape: {X_combined.shape}")

        #Save the combined multimodal dataset
        with open('processed_COMBINED_data.pkl', 'wb') as f:
            pickle.dump(combined_dict, f)

        print("Done!")

if __name__ == "__main__":
    load_and_combine_data()
# Out:
# Loadingprocessed_ACC_data.pkl
# Loadingprocessed_BVP_data.pkl
# Loadingprocessed_EDA_data.pkl
# SubjectS2 combined. New feature shape: (1943, 720)
# Done!
# SubjectS3 combined. New feature shape: (1977, 720)
# Done!
# SubjectS4 combined. New feature shape: (1987, 720)
# Done!
# SubjectS5 combined. New feature shape: (2039, 720)
# Done!
# SubjectS6 combined. New feature shape: (2024, 720)
# Done!
# SubjectS7 combined. New feature shape: (2020, 720)
# Done!
# SubjectS8 combined. New feature shape: (2030, 720)
# Done!
# SubjectS9 combined. New feature shape: (2019, 720)
# Done!
# SubjectS10 combined. New feature shape: (2099, 720)
# Done!
# SubjectS11 combined. New feature shape: (2050, 720)
# Done!
# SubjectS13 combined. New feature shape: (2047, 720)
# Done!
# SubjectS14 combined. New feature shape: (2049, 720)
# Done!
# SubjectS15 combined. New feature shape: (2055, 720)
# Done!
# SubjectS16 combined. New feature shape: (2043, 720)
# Done!
# SubjectS17 combined. New feature shape: (2098, 720)
# Done!

# %%
#Import the packages needed for the CNN model

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# %%
#Makes sure the input data has the right form for the 1D-CNN model, by changing the shape from (N, Length) to (N, 1, Length)
class WESADDataset(Dataset):
    """
    Converts the input arrays to PyTorch tensors and adds a channel 
    dimensions so the data can be used as input for the 1D-CNN model.
    The shape changes from (N, lenght) to (N, 1, length).
    """

    def __init__(self, X, y):

        #Convert NumPy arrays to PyTorch tensors and add a channel dimension
        self.X = torch.from_numpy(X).float().unsqueeze(1)

        #Convert labels to PyTorch tensors
        self.y = torch.from_numpy(y).float().unsqueeze(1)
    
    def __len__(self):
        #Return the number of samples
        return len(self.X)
    
    def __getitem__(self, idx):
        #Return a single sample and its corresponding label
        return self.X[idx], self.y[idx]

# %%
def get_loso_loaders(data_dict, test_subject, batch_size=32):
    """"
    Create training and test DataLoaders using Leave-One-Subject-Out (LOSO) cross-validation
    
    One subject is used as the test set, while the data from all remaining subjects is combined into the training set

    Parameters:
    data_dict: dict, Dictionary containing the data for each subject
    test_subject: str, Subject that will be used as the test set
    batch_size: int, optional, Number of samples per batch (default = 32)

    Returns:
    train_loader: DataLoader, DataLoader containing the training data
    test_loader: Dataloader, DataLoader containing the test data
    """
    #Separate the training and test subject
    subjects = list(data_dict.keys())
    train_subjects = [s for s in subjects if s != test_subject]

    #Combine all training subjects into one dataset
    X_train = np.concatenate([data_dict[s][0] for s in train_subjects], axis = 0)
    y_train = np.concatenate([data_dict[s][1] for s in train_subjects], axis = 0)

    #Use the selected subject as the test set
    X_test, y_test = data_dict[test_subject]

    #Convert the data to PyTorch datasets
    train_ds = WESADDataset(X_train, y_train)
    test_ds = WESADDataset(X_test, y_test)

    #Create DataLoaders for model training and evaluation
    train_loader = DataLoader(train_ds, batch_size = batch_size, shuffle = True)
    test_loader = DataLoader(test_ds, batch_size = batch_size, shuffle = False)

    return train_loader, test_loader

# %%
import torch
import torch.nn as nn

class Simple1DCNN(nn.Module):
    """
    Simple 1D Convolutional Neural Network for binary stress classification
    using wrist-based physiological signals.
    """

    def __init__(self, input_length):
        super(Simple1DCNN, self).__init__()
        
        #Feature extraction through stacked 1D Convolutional layers
        self.conv_layers = nn.Sequential(
            nn.Conv1d(1, 32, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.MaxPool1d(2),
            nn.Conv1d(32, 64, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.MaxPool1d(2),
            nn.Conv1d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(2)
        )

        #Compute flattened feature size after convolutions
        #Each MaxPool1d(2) halves the temporal dimension (3 pooling layers ->/8)
        self.flattened_size = (input_length // 8) * 128

        #Fully connected classification head
        self.fc1 = nn.Linear(self.flattened_size, 64)
        self.dropout = nn.Dropout(p=0.5)
        self.fc2 = nn.Linear(64, 1)

        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        #Pass through convolutional feature extractor
        x = self.conv_layers(x)

        #Flatten for fully connected layers
        x = x.view(x.size(0), -1)

        #Classification head
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)

        #Output probability (binary classification)
        x = self.sigmoid(x)

        return x

# %%
#Select the best available device for model training
#Priority: CUDA(GPU) -> MPS (Apple Silicon) -> CPU
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

#Print selected device for reproducibility/debugging
print(f"Device set to: {device}")
# Out:
# Device set to: cuda

# %%
# Simple test to verify that the Simple1DCNN model can be initialized
# And performs a correct forward pass without errors

# Create model instance (input length = 1920 time steps)
model = Simple1DCNN(1920)

# Create dummy input (batch_size=2, channels=1, signal length = 1920)
dummy_input = torch.randn(2, 1, 1920)

# Move model and input to the selected device (GPU/CPU)
model.to(device)
dummy_input = dummy_input.to(device)

# Forward pass through the model
output = model(dummy_input)

# Verify output shape
print(f"Input shape: {dummy_input.shape}")
print(f"Output shape: {output.shape}")

#Expected output: Binary classification -> One value per sample
print(f"Expected output shape: (2, 1)")

#Check correctness of output shape
assert output.shape == (2, 1), f"Expected shape (2, 1), got {output.shape}"

print("✓ Model initialization and forward pass successful!")
# Out:
# DEBUG: Model initialized with flattened_size = 30720
# Input shape: torch.Size([2, 1, 1920])
# Output shape: torch.Size([2, 1])
# Expected output shape: (2, 10)
# ✓ Model initialization and forward pass successful!

# %%
def train_model(model, train_loader, val_loader, epochs, criterion, optimizer):
    """
    Train and validate a binary classification model using PyTorch

    Track loss and accuracy for both training and validation sets for each epoch.

    """
    
    
    model.to(device)

    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(epochs):

        #Training phase

        model.train()

        total_train_loss = 0.0
        correct_train = 0
        total_train = 0

        for inputs, labels in train_loader:

            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()

            outputs = model(inputs)

            #Compute loss (ensure correct shape)
            loss = criterion(outputs, labels.float().view(-1, 1))

            loss.backward()
            optimizer.step()

            total_train_loss += loss.item()

            #Convert probabilities to binary predictions
            predicted = (outputs > 0.5).float()

            total_train += labels.size(0)
            correct_train += (predicted == labels.view(-1, 1)).sum().item()
        
        avg_train_loss = total_train_loss / len(train_loader)
        train_accuracy = correct_train / total_train

        train_losses.append(avg_train_loss)
        train_accuracies.append(train_accuracy)

        #Validation phase

        model.eval()

        total_val_loss = 0.0
        correct_val = 0
        total_val = 0

        with torch.no_grad():
            for val_inputs, val_labels in val_loader:

                val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)
                
                val_outputs = model(val_inputs)

                #Match training loss shape
                val_loss = criterion(val_outputs, val_labels.float())

                total_val_loss += val_loss.item()

                #Binary classification threshold
                predicted_val = (val_outputs > 0.5).float()
                
                total_val += val_labels.size(0)
                correct_val += (predicted_val == val_labels).sum().item()

        avg_val_loss = total_val_loss / len(val_loader)
        val_accuracy = correct_val / total_val

        val_losses.append(avg_val_loss)
        val_accuracies.append(val_accuracy)

        print(f"Epoch {epoch+1}/{epochs} | Train Loss: {avg_train_loss:.4f} Acc: {train_accuracy:.4f} | Val Loss: {avg_val_loss:.4f} Acc: {val_accuracy:.4f}")

    return train_losses, val_losses, train_accuracies, val_accuracies

# %%
def get_predictions(model, loader, device):
    """
    Generate binary predictions for a dataset using a trained model.

    Parameters:
    model: torch.nn.Module, Trained PyTorch model
    loader: DataLoader, DataLoader containing the dataset to evaluate
    device: torch.device, Device used for computation (CPU/GPU)

    Returns:
    all_preds: np.array, Predicted binary labels (0 or 1)
    all_labels: np.array, Ground truth labels.
    """
    model.eval()

    all_preds, all_labels = [], []

    with torch.no_grad():
        for inputs, labels in loader:

            #Move input data to the correct device
            inputs = inputs.to(device)

            #Forward pass
            outputs = model(inputs)

            #Convert probabilities to binary predictions
            preds = (outputs > 0.5).float()

            #Store predictions and true labels
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.numpy())
            
    return np.array(all_preds), np.array(all_labels)

# %%
#Test forward pass of the trained model using dummy input

#Batch size = 32, 1 channel, signal length = 240 (adjust to model input length)
test_input = torch.randn(32, 1, 960).to(device)

try:
    output = model(test_input)

    #Verify output shape (binary classification -> one output per sample)
    print(f"Success! Output shape: {output.shape}") #Expected: [32, 1]

except Exception as e:
    print(f"Still failing: {e}")
# Out:
# Success! Output shape: torch.Size([32, 2])

# %%
#Create directory to store trained model checkpoints
#Change path to model name for each trained model

model_save_path = f"models_COMBINED-TEMP_2"
os.makedirs(model_save_path, exist_ok = True)

# %%
#Experiment configuration
CURRENT_SIGNAL_TYPE = 'COMBINED-TEMP'

#Input length of the model (depends on preprocessing step)
INPUT_LENGTH = 720 #1920 for ACC, 3840 for BVP, 240 for EDA and TEMP

EPOCHS = 20
BATCH_SIZE = 32
LEARNING_RATE = 0.0001

#Select device (GPU if availble, otherwise CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load the data

with open('processed_COMBINED-TEMP_data.pkl', 'rb') as f:
    data_dict = pickle.load(f)

all_loso_results = {}

#Leave-One-Subject-Out (LOSO) evaluation

for test_subject in data_dict.keys():

    #Create train/test splits
    train_loader, test_loader = get_loso_loaders(data_dict, test_subject, BATCH_SIZE)

    #Initialize model
    model = Simple1DCNN(input_length = INPUT_LENGTH).to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr = LEARNING_RATE, weight_decay=1e-4)
    
    criterion = torch.nn.BCELoss()

    #Train model
    t_losses, v_losses, t_accs, v_accs = train_model(model, train_loader, test_loader, EPOCHS, criterion, optimizer)
    
    #Generate predictions
    y_pred, y_true = get_predictions(model, test_loader, device)
    
    #Store results per subject
    all_loso_results[test_subject] = {
        'train_losses': t_losses,
        'val_losses': v_losses,
        'train_accs': t_accs,
        'val_accs': v_accs,
        'y_true': y_true,
        'y_pred': y_pred,
        'final_accuracy': v_accs[-1]
    }

    # Save results after each subject (safe checkpointing)
    with open(f'results_{CURRENT_SIGNAL_TYPE}_LOSO_BINARY3.pkl', 'wb') as f:
        pickle.dump(all_loso_results, f)

    #Save model weights per subject
    full_path = os.path.join(model_save_path, f"model_{test_subject}.pth")

    torch.save(model.state_dict(), full_path)
    
    print(f"✓ Finished {test_subject}. Accuracy: {v_accs[-1]*100:.2f}%")
# Out:
# DEBUG: Model initialized with flattened_size = 11520
# Epoch 1/20 | Train Loss: 0.3820 Acc: 0.8069 | Val Loss: 0.1889 Acc: 0.9614
# Epoch 2/20 | Train Loss: 0.1709 Acc: 0.9315 | Val Loss: 0.1511 Acc: 0.9604
# Epoch 3/20 | Train Loss: 0.0914 Acc: 0.9652 | Val Loss: 0.2232 Acc: 0.9326
# Epoch 4/20 | Train Loss: 0.0528 Acc: 0.9788 | Val Loss: 0.2229 Acc: 0.9527
# Epoch 5/20 | Train Loss: 0.0339 Acc: 0.9862 | Val Loss: 0.1826 Acc: 0.9619
# Epoch 6/20 | Train Loss: 0.0188 Acc: 0.9956 | Val Loss: 0.7905 Acc: 0.9619
# Epoch 7/20 | Train Loss: 0.0152 Acc: 0.9960 | Val Loss: 1.0552 Acc: 0.9609
# Epoch 8/20 | Train Loss: 0.0087 Acc: 0.9982 | Val Loss: 1.1759 Acc: 0.9341
# Epoch 9/20 | Train Loss: 0.0053 Acc: 0.9989 | Val Loss: 1.1206 Acc: 0.9393
# Epoch 10/20 | Train Loss: 0.0063 Acc: 0.9984 | Val Loss: 1.0871 Acc: 0.9547
# Epoch 11/20 | Train Loss: 0.0027 Acc: 0.9996 | Val Loss: 1.3494 Acc: 0.9732
# Epoch 12/20 | Train Loss: 0.0046 Acc: 0.9990 | Val Loss: 1.1714 Acc: 0.9537
# Epoch 13/20 | Train Loss: 0.0060 Acc: 0.9984 | Val Loss: 1.0644 Acc: 0.9527
# Epoch 14/20 | Train Loss: 0.0015 Acc: 0.9997 | Val Loss: 1.2043 Acc: 0.9460
# Epoch 15/20 | Train Loss: 0.0008 Acc: 1.0000 | Val Loss: 1.4227 Acc: 0.9279
# Epoch 16/20 | Train Loss: 0.0058 Acc: 0.9984 | Val Loss: 1.2196 Acc: 0.9696
# Epoch 17/20 | Train Loss: 0.0009 Acc: 0.9999 | Val Loss: 1.2573 Acc: 0.9738
# Epoch 18/20 | Train Loss: 0.0132 Acc: 0.9974 | Val Loss: 1.0366 Acc: 0.9707
# Epoch 19/20 | Train Loss: 0.0011 Acc: 0.9999 | Val Loss: 1.3325 Acc: 0.9645
# Epoch 20/20 | Train Loss: 0.0021 Acc: 0.9995 | Val Loss: 1.1697 Acc: 0.9599
# ✓ Finished S2. Accuracy: 95.99%
# DEBUG: Model initialized with flattened_size = 11520
# Epoch 1/20 | Train Loss: 0.3367 Acc: 0.8467 | Val Loss: 0.6763 Acc: 0.7021
# Epoch 2/20 | Train Loss: 0.1335 Acc: 0.9533 | Val Loss: 0.8112 Acc: 0.6854
# Epoch 3/20 | Train Loss: 0.0604 Acc: 0.9821 | Val Loss: 1.1607 Acc: 0.6601
# Epoch 4/20 | Train Loss: 0.0325 Acc: 0.9907 | Val Loss: 1.0689 Acc: 0.7051
# Epoch 5/20 | Train Loss: 0.0214 Acc: 0.9945 | Val Loss: 1.5517 Acc: 0.6823
# Epoch 6/20 | Train Loss: 0.0107 Acc: 0.9976 | Val Loss: 1.6287 Acc: 0.6899
# Epoch 7/20 | Train Loss: 0.0056 Acc: 0.9989 | Val Loss: 1.3138 Acc: 0.7395
# Epoch 8/20 | Train Loss: 0.0056 Acc: 0.9989 | Val Loss: 1.6641 Acc: 0.7097
# Epoch 9/20 | Train Loss: 0.0069 Acc: 0.9982 | Val Loss: 1.6607 Acc: 0.6985
# Epoch 10/20 | Train Loss: 0.0035 Acc: 0.9994 | Val Loss: 2.6172 Acc: 0.6823
# Epoch 11/20 | Train Loss: 0.0027 Acc: 0.9994 | Val Loss: 1.9441 Acc: 0.6920
# Epoch 12/20 | Train Loss: 0.0022 Acc: 0.9996 | Val Loss: 1.8538 Acc: 0.7441
# Epoch 13/20 | Train Loss: 0.0029 Acc: 0.9994 | Val Loss: 2.9946 Acc: 0.7046
# Epoch 14/20 | Train Loss: 0.0021 Acc: 0.9995 | Val Loss: 3.6567 Acc: 0.7370
# Epoch 15/20 | Train Loss: 0.0046 Acc: 0.9988 | Val Loss: 3.0803 Acc: 0.6611
# Epoch 16/20 | Train Loss: 0.0015 Acc: 0.9996 | Val Loss: 4.1316 Acc: 0.6975
# Epoch 17/20 | Train Loss: 0.0006 Acc: 1.0000 | Val Loss: 4.1500 Acc: 0.7041
# Epoch 18/20 | Train Loss: 0.0067 Acc: 0.9979 | Val Loss: 3.4560 Acc: 0.7213
# Epoch 19/20 | Train Loss: 0.0007 Acc: 1.0000 | Val Loss: 4.2539 Acc: 0.7228
# Epoch 20/20 | Train Loss: 0.0007 Acc: 0.9999 | Val Loss: 5.7796 Acc: 0.6758
# ✓ Finished S3. Accuracy: 67.58%
# DEBUG: Model initialized with flattened_size = 11520
# Epoch 1/20 | Train Loss: 0.3693 Acc: 0.8322 | Val Loss: 0.1211 Acc: 0.9597
# Epoch 2/20 | Train Loss: 0.1697 Acc: 0.9395 | Val Loss: 0.5035 Acc: 0.8374
# Epoch 3/20 | Train Loss: 0.0896 Acc: 0.9709 | Val Loss: 0.6076 Acc: 0.8430
# Epoch 4/20 | Train Loss: 0.0523 Acc: 0.9842 | Val Loss: 1.2862 Acc: 0.7846
# Epoch 5/20 | Train Loss: 0.0225 Acc: 0.9943 | Val Loss: 1.1735 Acc: 0.8218
# Epoch 6/20 | Train Loss: 0.0296 Acc: 0.9916 | Val Loss: 0.7849 Acc: 0.8752
# Epoch 7/20 | Train Loss: 0.0155 Acc: 0.9972 | Val Loss: 1.3752 Acc: 0.8188
# Epoch 8/20 | Train Loss: 0.0104 Acc: 0.9972 | Val Loss: 1.3011 Acc: 0.8334
# Epoch 9/20 | Train Loss: 0.0069 Acc: 0.9986 | Val Loss: 0.9635 Acc: 0.8802
# Epoch 10/20 | Train Loss: 0.0051 Acc: 0.9988 | Val Loss: 0.9022 Acc: 0.8958
# Epoch 11/20 | Train Loss: 0.0039 Acc: 0.9991 | Val Loss: 1.2384 Acc: 0.8500
# Epoch 12/20 | Train Loss: 0.0040 Acc: 0.9990 | Val Loss: 0.9759 Acc: 0.8983
# Epoch 13/20 | Train Loss: 0.0056 Acc: 0.9988 | Val Loss: 1.0906 Acc: 0.8737
# Epoch 14/20 | Train Loss: 0.0011 Acc: 0.9999 | Val Loss: 1.2235 Acc: 0.8873
# Epoch 15/20 | Train Loss: 0.0102 Acc: 0.9972 | Val Loss: 0.5011 Acc: 0.9305
# Epoch 16/20 | Train Loss: 0.0011 Acc: 0.9999 | Val Loss: 0.7538 Acc: 0.9255
# Epoch 17/20 | Train Loss: 0.0009 Acc: 0.9999 | Val Loss: 1.6444 Acc: 0.8309
# Epoch 18/20 | Train Loss: 0.0057 Acc: 0.9983 | Val Loss: 1.3519 Acc: 0.8691
# Epoch 19/20 | Train Loss: 0.0008 Acc: 1.0000 | Val Loss: 0.9650 Acc: 0.8988
# Epoch 20/20 | Train Loss: 0.0031 Acc: 0.9994 | Val Loss: 2.3004 Acc: 0.7947
# ✓ Finished S4. Accuracy: 79.47%
# DEBUG: Model initialized with flattened_size = 11520
# Epoch 1/20 | Train Loss: 0.3368 Acc: 0.8479 | Val Loss: 0.8034 Acc: 0.6871
# Epoch 2/20 | Train Loss: 0.1571 Acc: 0.9420 | Val Loss: 0.3511 Acc: 0.8568
# Epoch 3/20 | Train Loss: 0.0873 Acc: 0.9689 | Val Loss: 0.4449 Acc: 0.8686
# Epoch 4/20 | Train Loss: 0.0447 Acc: 0.9866 | Val Loss: 0.5503 Acc: 0.8843
# Epoch 5/20 | Train Loss: 0.0280 Acc: 0.9921 | Val Loss: 1.1044 Acc: 0.8906
# Epoch 6/20 | Train Loss: 0.0180 Acc: 0.9951 | Val Loss: 1.2938 Acc: 0.8965
# Epoch 7/20 | Train Loss: 0.0097 Acc: 0.9976 | Val Loss: 1.8055 Acc: 0.8926
# Epoch 8/20 | Train Loss: 0.0216 Acc: 0.9936 | Val Loss: 1.1645 Acc: 0.9137
# Epoch 9/20 | Train Loss: 0.0057 Acc: 0.9988 | Val Loss: 1.2316 Acc: 0.9019
# Epoch 10/20 | Train Loss: 0.0128 Acc: 0.9969 | Val Loss: 0.6818 Acc: 0.9117
# Epoch 11/20 | Train Loss: 0.0043 Acc: 0.9992 | Val Loss: 1.9824 Acc: 0.9264
# Epoch 12/20 | Train Loss: 0.0106 Acc: 0.9974 | Val Loss: 6.2326 Acc: 0.8641
# Epoch 13/20 | Train Loss: 0.0032 Acc: 0.9994 | Val Loss: 5.6057 Acc: 0.8720
# Epoch 14/20 | Train Loss: 0.0029 Acc: 0.9994 | Val Loss: 1.4465 Acc: 0.8965
# Epoch 15/20 | Train Loss: 0.0175 Acc: 0.9966 | Val Loss: 0.7118 Acc: 0.9264
# Epoch 16/20 | Train Loss: 0.0015 Acc: 0.9999 | Val Loss: 1.6835 Acc: 0.9338
# Epoch 17/20 | Train Loss: 0.0008 Acc: 1.0000 | Val Loss: 2.9778 Acc: 0.9323
# Epoch 18/20 | Train Loss: 0.0041 Acc: 0.9992 | Val Loss: 0.5922 Acc: 0.8960
# Epoch 19/20 | Train Loss: 0.0043 Acc: 0.9990 | Val Loss: 3.5957 Acc: 0.9259
# Epoch 20/20 | Train Loss: 0.0013 Acc: 0.9997 | Val Loss: 4.4578 Acc: 0.8818
# ✓ Finished S5. Accuracy: 88.18%
# DEBUG: Model initialized with flattened_size = 11520
# Epoch 1/20 | Train Loss: 0.3296 Acc: 0.8513 | Val Loss: 0.2887 Acc: 0.8340
# Epoch 2/20 | Train Loss: 0.1519 Acc: 0.9443 | Val Loss: 0.2197 Acc: 0.8661
# Epoch 3/20 | Train Loss: 0.0689 Acc: 0.9776 | Val Loss: 0.3925 Acc: 0.8424
# Epoch 4/20 | Train Loss: 0.0304 Acc: 0.9919 | Val Loss: 0.4148 Acc: 0.8429
# Epoch 5/20 | Train Loss: 0.0310 Acc: 0.9909 | Val Loss: 0.4359 Acc: 0.8483
# Epoch 6/20 | Train Loss: 0.0113 Acc: 0.9973 | Val Loss: 0.6602 Acc: 0.8300
# Epoch 7/20 | Train Loss: 0.0037 Acc: 0.9998 | Val Loss: 0.6562 Acc: 0.8498
# Epoch 8/20 | Train Loss: 0.0111 Acc: 0.9972 | Val Loss: 0.5328 Acc: 0.8547
# Epoch 9/20 | Train Loss: 0.0023 Acc: 0.9997 | Val Loss: 0.7007 Acc: 0.8513
# Epoch 10/20 | Train Loss: 0.0041 Acc: 0.9992 | Val Loss: 1.9193 Acc: 0.7465
# Epoch 11/20 | Train Loss: 0.0061 Acc: 0.9988 | Val Loss: 1.0898 Acc: 0.7362
# Epoch 12/20 | Train Loss: 0.0030 Acc: 0.9994 | Val Loss: 0.8219 Acc: 0.8508
# Epoch 13/20 | Train Loss: 0.0081 Acc: 0.9985 | Val Loss: 0.5755 Acc: 0.8641
# Epoch 14/20 | Train Loss: 0.0013 Acc: 0.9999 | Val Loss: 0.8041 Acc: 0.8533
# Epoch 15/20 | Train Loss: 0.0008 Acc: 1.0000 | Val Loss: 0.8834 Acc: 0.8552
# Epoch 16/20 | Train Loss: 0.0037 Acc: 0.9992 | Val Loss: 0.8196 Acc: 0.8557
# Epoch 17/20 | Train Loss: 0.0006 Acc: 1.0000 | Val Loss: 0.8816 Acc: 0.8498
# Epoch 18/20 | Train Loss: 0.0054 Acc: 0.9983 | Val Loss: 0.8871 Acc: 0.8034
# Epoch 19/20 | Train Loss: 0.0008 Acc: 1.0000 | Val Loss: 1.0903 Acc: 0.8261
# Epoch 20/20 | Train Loss: 0.0004 Acc: 1.0000 | Val Loss: 1.0384 Acc: 0.8473
# ✓ Finished S6. Accuracy: 84.73%
# DEBUG: Model initialized with flattened_size = 11520
# Epoch 1/20 | Train Loss: 0.3406 Acc: 0.8444 | Val Loss: 0.3609 Acc: 0.8312
# Epoch 2/20 | Train Loss: 0.1488 Acc: 0.9464 | Val Loss: 0.1610 Acc: 0.9129
# Epoch 3/20 | Train Loss: 0.0795 Acc: 0.9748 | Val Loss: 0.1158 Acc: 0.9406
# Epoch 4/20 | Train Loss: 0.0403 Acc: 0.9881 | Val Loss: 0.2414 Acc: 0.8738
# Epoch 5/20 | Train Loss: 0.0214 Acc: 0.9945 | Val Loss: 0.1087 Acc: 0.9416
# Epoch 6/20 | Train Loss: 0.0133 Acc: 0.9972 | Val Loss: 0.0524 Acc: 0.9777
# Epoch 7/20 | Train Loss: 0.0168 Acc: 0.9958 | Val Loss: 0.0391 Acc: 0.9856
# Epoch 8/20 | Train Loss: 0.0042 Acc: 0.9994 | Val Loss: 0.0819 Acc: 0.9569
# Epoch 9/20 | Train Loss: 0.0032 Acc: 0.9997 | Val Loss: 0.2304 Acc: 0.9045
# Epoch 10/20 | Train Loss: 0.0082 Acc: 0.9980 | Val Loss: 0.1336 Acc: 0.9401
# Epoch 11/20 | Train Loss: 0.0036 Acc: 0.9993 | Val Loss: 0.1309 Acc: 0.9441
# Epoch 12/20 | Train Loss: 0.0044 Acc: 0.9990 | Val Loss: 0.0380 Acc: 0.9851
# Epoch 13/20 | Train Loss: 0.0015 Acc: 0.9999 | Val Loss: 0.0162 Acc: 0.9950
# Epoch 14/20 | Train Loss: 0.0010 Acc: 0.9999 | Val Loss: 0.1498 Acc: 0.9450
# Epoch 15/20 | Train Loss: 0.0022 Acc: 0.9994 | Val Loss: 0.0458 Acc: 0.9772
# Epoch 16/20 | Train Loss: 0.0025 Acc: 0.9995 | Val Loss: 0.0721 Acc: 0.9693
# Epoch 17/20 | Train Loss: 0.0007 Acc: 0.9999 | Val Loss: 0.1144 Acc: 0.9535
# Epoch 18/20 | Train Loss: 0.0112 Acc: 0.9971 | Val Loss: 0.1084 Acc: 0.9446
# Epoch 19/20 | Train Loss: 0.0014 Acc: 0.9998 | Val Loss: 0.0658 Acc: 0.9653
# Epoch 20/20 | Train Loss: 0.0008 Acc: 0.9999 | Val Loss: 0.0988 Acc: 0.9589
# ✓ Finished S7. Accuracy: 95.89%
# DEBUG: Model initialized with flattened_size = 11520
# Epoch 1/20 | Train Loss: 0.3619 Acc: 0.8382 | Val Loss: 0.1098 Acc: 0.9532
# Epoch 2/20 | Train Loss: 0.1723 Acc: 0.9347 | Val Loss: 0.1885 Acc: 0.9202
# Epoch 3/20 | Train Loss: 0.0970 Acc: 0.9652 | Val Loss: 0.3580 Acc: 0.9099
# Epoch 4/20 | Train Loss: 0.0573 Acc: 0.9819 | Val Loss: 1.1083 Acc: 0.7788
# Epoch 5/20 | Train Loss: 0.0318 Acc: 0.9909 | Val Loss: 0.4465 Acc: 0.9084
# Epoch 6/20 | Train Loss: 0.0267 Acc: 0.9930 | Val Loss: 0.7829 Acc: 0.8695
# Epoch 7/20 | Train Loss: 0.0142 Acc: 0.9966 | Val Loss: 0.5868 Acc: 0.9044
# Epoch 8/20 | Train Loss: 0.0148 Acc: 0.9962 | Val Loss: 0.6823 Acc: 0.9015
# Epoch 9/20 | Train Loss: 0.0062 Acc: 0.9989 | Val Loss: 1.5547 Acc: 0.8039
# Epoch 10/20 | Train Loss: 0.0079 Acc: 0.9982 | Val Loss: 0.5688 Acc: 0.9246
# Epoch 11/20 | Train Loss: 0.0062 Acc: 0.9986 | Val Loss: 0.7967 Acc: 0.8995
# Epoch 12/20 | Train Loss: 0.0039 Acc: 0.9992 | Val Loss: 0.7797 Acc: 0.8951
# Epoch 13/20 | Train Loss: 0.0102 Acc: 0.9979 | Val Loss: 0.5151 Acc: 0.9099
# Epoch 14/20 | Train Loss: 0.0024 Acc: 0.9995 | Val Loss: 0.7639 Acc: 0.9054
# Epoch 15/20 | Train Loss: 0.0012 Acc: 0.9999 | Val Loss: 0.9120 Acc: 0.8980
# Epoch 16/20 | Train Loss: 0.0066 Acc: 0.9983 | Val Loss: 0.7763 Acc: 0.9059
# Epoch 17/20 | Train Loss: 0.0013 Acc: 0.9998 | Val Loss: 2.3337 Acc: 0.7640
# Epoch 18/20 | Train Loss: 0.0082 Acc: 0.9980 | Val Loss: 0.8102 Acc: 0.9005
# Epoch 19/20 | Train Loss: 0.0007 Acc: 1.0000 | Val Loss: 0.8476 Acc: 0.9064
# Epoch 20/20 | Train Loss: 0.0015 Acc: 0.9997 | Val Loss: 0.7163 Acc: 0.9197
# ✓ Finished S8. Accuracy: 91.97%
# DEBUG: Model initialized with flattened_size = 11520
# Epoch 1/20 | Train Loss: 0.3249 Acc: 0.8508 | Val Loss: 0.5659 Acc: 0.8227
# Epoch 2/20 | Train Loss: 0.1486 Acc: 0.9442 | Val Loss: 0.4256 Acc: 0.8687
# Epoch 3/20 | Train Loss: 0.0724 Acc: 0.9765 | Val Loss: 0.4087 Acc: 0.8757
# Epoch 4/20 | Train Loss: 0.0395 Acc: 0.9879 | Val Loss: 0.9136 Acc: 0.8474
# Epoch 5/20 | Train Loss: 0.0205 Acc: 0.9944 | Val Loss: 0.6003 Acc: 0.8796
# Epoch 6/20 | Train Loss: 0.0147 Acc: 0.9965 | Val Loss: 1.0665 Acc: 0.8653
# Epoch 7/20 | Train Loss: 0.0112 Acc: 0.9973 | Val Loss: 0.9927 Acc: 0.8717
# Epoch 8/20 | Train Loss: 0.0068 Acc: 0.9985 | Val Loss: 0.9991 Acc: 0.8697
# Epoch 9/20 | Train Loss: 0.0037 Acc: 0.9992 | Val Loss: 1.1209 Acc: 0.8767
# Epoch 10/20 | Train Loss: 0.0086 Acc: 0.9981 | Val Loss: 1.1401 Acc: 0.8762
# Epoch 11/20 | Train Loss: 0.0015 Acc: 0.9999 | Val Loss: 1.1207 Acc: 0.8737
# Epoch 12/20 | Train Loss: 0.0092 Acc: 0.9978 | Val Loss: 1.0846 Acc: 0.8747
# Epoch 13/20 | Train Loss: 0.0026 Acc: 0.9995 | Val Loss: 1.1223 Acc: 0.8767
# Epoch 14/20 | Train Loss: 0.0006 Acc: 1.0000 | Val Loss: 1.1690 Acc: 0.8757
# Epoch 15/20 | Train Loss: 0.0070 Acc: 0.9985 | Val Loss: 1.0782 Acc: 0.8752
# Epoch 16/20 | Train Loss: 0.0022 Acc: 0.9995 | Val Loss: 1.0800 Acc: 0.8811
# Epoch 17/20 | Train Loss: 0.0039 Acc: 0.9987 | Val Loss: 1.3262 Acc: 0.8108
# Epoch 18/20 | Train Loss: 0.0024 Acc: 0.9995 | Val Loss: 1.1017 Acc: 0.8801
# Epoch 19/20 | Train Loss: 0.0018 Acc: 0.9997 | Val Loss: 1.3390 Acc: 0.8772
# Epoch 20/20 | Train Loss: 0.0059 Acc: 0.9993 | Val Loss: 0.9828 Acc: 0.8935
# ✓ Finished S9. Accuracy: 89.35%
# DEBUG: Model initialized with flattened_size = 11520
# Epoch 1/20 | Train Loss: 0.4192 Acc: 0.7772 | Val Loss: 0.5928 Acc: 0.5331
# Epoch 2/20 | Train Loss: 0.2685 Acc: 0.8623 | Val Loss: 0.3999 Acc: 0.7599
# Epoch 3/20 | Train Loss: 0.1692 Acc: 0.9227 | Val Loss: 0.1209 Acc: 0.9547
# Epoch 4/20 | Train Loss: 0.1053 Acc: 0.9549 | Val Loss: 0.2999 Acc: 0.8480
# Epoch 5/20 | Train Loss: 0.0715 Acc: 0.9782 | Val Loss: 0.0912 Acc: 0.9557
# Epoch 6/20 | Train Loss: 0.0503 Acc: 0.9859 | Val Loss: 0.2309 Acc: 0.9319
# Epoch 7/20 | Train Loss: 0.0369 Acc: 0.9891 | Val Loss: 0.5721 Acc: 0.8442
# Epoch 8/20 | Train Loss: 0.0258 Acc: 0.9919 | Val Loss: 0.5768 Acc: 0.8676
# Epoch 9/20 | Train Loss: 0.0244 Acc: 0.9920 | Val Loss: 0.5401 Acc: 0.8814
# Epoch 10/20 | Train Loss: 0.0151 Acc: 0.9947 | Val Loss: 0.3810 Acc: 0.9214
# Epoch 11/20 | Train Loss: 0.0108 Acc: 0.9957 | Val Loss: 1.0031 Acc: 0.7994
# Epoch 12/20 | Train Loss: 0.0073 Acc: 0.9963 | Val Loss: 0.6132 Acc: 0.8976
# Epoch 13/20 | Train Loss: 0.0106 Acc: 0.9961 | Val Loss: 0.6741 Acc: 0.8652
# Epoch 14/20 | Train Loss: 0.0079 Acc: 0.9979 | Val Loss: 0.6503 Acc: 0.8852
# Epoch 15/20 | Train Loss: 0.0040 Acc: 0.9991 | Val Loss: 1.0405 Acc: 0.8533
# Epoch 16/20 | Train Loss: 0.0100 Acc: 0.9975 | Val Loss: 0.8062 Acc: 0.8785
# Epoch 17/20 | Train Loss: 0.0031 Acc: 0.9993 | Val Loss: 1.5204 Acc: 0.8294
# Epoch 18/20 | Train Loss: 0.0033 Acc: 0.9991 | Val Loss: 3.6141 Acc: 0.7837
# Epoch 19/20 | Train Loss: 0.0052 Acc: 0.9982 | Val Loss: 0.8539 Acc: 0.8904
# Epoch 20/20 | Train Loss: 0.0010 Acc: 0.9998 | Val Loss: 3.4845 Acc: 0.8047
# ✓ Finished S10. Accuracy: 80.47%
# DEBUG: Model initialized with flattened_size = 11520
# Epoch 1/20 | Train Loss: 0.3195 Acc: 0.8517 | Val Loss: 0.1225 Acc: 1.0000
# Epoch 2/20 | Train Loss: 0.1156 Acc: 0.9592 | Val Loss: 0.2457 Acc: 0.8980
# Epoch 3/20 | Train Loss: 0.0480 Acc: 0.9860 | Val Loss: 0.3588 Acc: 0.8420
# Epoch 4/20 | Train Loss: 0.0250 Acc: 0.9930 | Val Loss: 0.0771 Acc: 0.9722
# Epoch 5/20 | Train Loss: 0.0137 Acc: 0.9970 | Val Loss: 0.5950 Acc: 0.8210
# Epoch 6/20 | Train Loss: 0.0082 Acc: 0.9981 | Val Loss: 0.7968 Acc: 0.7912
# Epoch 7/20 | Train Loss: 0.0115 Acc: 0.9979 | Val Loss: 0.4766 Acc: 0.8507
# Epoch 8/20 | Train Loss: 0.0025 Acc: 0.9999 | Val Loss: 0.3000 Acc: 0.9063
# Epoch 9/20 | Train Loss: 0.0086 Acc: 0.9977 | Val Loss: 0.4973 Acc: 0.8693
# Epoch 10/20 | Train Loss: 0.0014 Acc: 0.9999 | Val Loss: 0.5749 Acc: 0.8688
# Epoch 11/20 | Train Loss: 0.0087 Acc: 0.9978 | Val Loss: 0.6223 Acc: 0.8449
# Epoch 12/20 | Train Loss: 0.0033 Acc: 0.9992 | Val Loss: 0.3380 Acc: 0.9034
# Epoch 13/20 | Train Loss: 0.0062 Acc: 0.9985 | Val Loss: 0.6018 Acc: 0.8527
# Epoch 14/20 | Train Loss: 0.0010 Acc: 0.9999 | Val Loss: 0.9716 Acc: 0.8146
# Epoch 15/20 | Train Loss: 0.0006 Acc: 1.0000 | Val Loss: 0.8650 Acc: 0.8312
# Epoch 16/20 | Train Loss: 0.0048 Acc: 0.9988 | Val Loss: 0.7297 Acc: 0.8444
# Epoch 17/20 | Train Loss: 0.0016 Acc: 0.9996 | Val Loss: 0.8156 Acc: 0.8322
# Epoch 18/20 | Train Loss: 0.0017 Acc: 0.9996 | Val Loss: 0.7930 Acc: 0.8415
# Epoch 19/20 | Train Loss: 0.0010 Acc: 0.9998 | Val Loss: 0.0196 Acc: 0.9898
# Epoch 20/20 | Train Loss: 0.0039 Acc: 0.9989 | Val Loss: 0.7192 Acc: 0.8507
# ✓ Finished S11. Accuracy: 85.07%
# DEBUG: Model initialized with flattened_size = 11520
# Epoch 1/20 | Train Loss: 0.3115 Acc: 0.8623 | Val Loss: 1.4289 Acc: 0.3781
# Epoch 2/20 | Train Loss: 0.1280 Acc: 0.9536 | Val Loss: 2.0674 Acc: 0.4201
# Epoch 3/20 | Train Loss: 0.0562 Acc: 0.9833 | Val Loss: 1.5893 Acc: 0.5916
# Epoch 4/20 | Train Loss: 0.0298 Acc: 0.9915 | Val Loss: 4.3898 Acc: 0.3693
# Epoch 5/20 | Train Loss: 0.0134 Acc: 0.9969 | Val Loss: 5.2246 Acc: 0.3683
# Epoch 6/20 | Train Loss: 0.0173 Acc: 0.9954 | Val Loss: 3.6114 Acc: 0.4079
# Epoch 7/20 | Train Loss: 0.0041 Acc: 0.9995 | Val Loss: 6.7452 Acc: 0.3947
# Epoch 8/20 | Train Loss: 0.0067 Acc: 0.9985 | Val Loss: 7.5951 Acc: 0.3791
# Epoch 9/20 | Train Loss: 0.0047 Acc: 0.9990 | Val Loss: 5.3926 Acc: 0.4187
# Epoch 10/20 | Train Loss: 0.0018 Acc: 0.9997 | Val Loss: 24.7402 Acc: 0.3317
# Epoch 11/20 | Train Loss: 0.0073 Acc: 0.9981 | Val Loss: 4.0360 Acc: 0.4314
# Epoch 12/20 | Train Loss: 0.0013 Acc: 0.9999 | Val Loss: 5.8068 Acc: 0.4636
# Epoch 13/20 | Train Loss: 0.0027 Acc: 0.9993 | Val Loss: 7.9124 Acc: 0.3693
# Epoch 14/20 | Train Loss: 0.0079 Acc: 0.9981 | Val Loss: 3.5638 Acc: 0.4519
# Epoch 15/20 | Train Loss: 0.0009 Acc: 1.0000 | Val Loss: 6.2590 Acc: 0.4333
# Epoch 16/20 | Train Loss: 0.0057 Acc: 0.9986 | Val Loss: 6.1630 Acc: 0.4050
# Epoch 17/20 | Train Loss: 0.0006 Acc: 1.0000 | Val Loss: 6.2494 Acc: 0.4358
# Epoch 18/20 | Train Loss: 0.0005 Acc: 1.0000 | Val Loss: 9.2118 Acc: 0.4162
# Epoch 19/20 | Train Loss: 0.0163 Acc: 0.9960 | Val Loss: 4.5188 Acc: 0.3659
# Epoch 20/20 | Train Loss: 0.0010 Acc: 0.9999 | Val Loss: 9.1618 Acc: 0.4138
# ✓ Finished S13. Accuracy: 41.38%
# DEBUG: Model initialized with flattened_size = 11520
# Epoch 1/20 | Train Loss: 0.3360 Acc: 0.8504 | Val Loss: 1.2776 Acc: 0.6994
# Epoch 2/20 | Train Loss: 0.1626 Acc: 0.9390 | Val Loss: 1.0725 Acc: 0.7394
# Epoch 3/20 | Train Loss: 0.0928 Acc: 0.9685 | Val Loss: 1.3722 Acc: 0.7199
# Epoch 4/20 | Train Loss: 0.0498 Acc: 0.9855 | Val Loss: 0.9761 Acc: 0.7906
# Epoch 5/20 | Train Loss: 0.0353 Acc: 0.9903 | Val Loss: 0.7337 Acc: 0.8141
# Epoch 6/20 | Train Loss: 0.0177 Acc: 0.9966 | Val Loss: 1.5134 Acc: 0.7745
# Epoch 7/20 | Train Loss: 0.0114 Acc: 0.9976 | Val Loss: 1.6452 Acc: 0.7750
# Epoch 8/20 | Train Loss: 0.0059 Acc: 0.9994 | Val Loss: 1.4757 Acc: 0.7867
# Epoch 9/20 | Train Loss: 0.0093 Acc: 0.9980 | Val Loss: 2.1492 Acc: 0.7540
# Epoch 10/20 | Train Loss: 0.0077 Acc: 0.9983 | Val Loss: 1.5891 Acc: 0.7833
# Epoch 11/20 | Train Loss: 0.0088 Acc: 0.9979 | Val Loss: 2.1928 Acc: 0.7657
# Epoch 12/20 | Train Loss: 0.0031 Acc: 0.9994 | Val Loss: 1.6082 Acc: 0.7862
# Epoch 13/20 | Train Loss: 0.0018 Acc: 0.9998 | Val Loss: 2.7513 Acc: 0.7516
# Epoch 14/20 | Train Loss: 0.0038 Acc: 0.9991 | Val Loss: 1.8639 Acc: 0.7857
# Epoch 15/20 | Train Loss: 0.0013 Acc: 0.9998 | Val Loss: 2.2277 Acc: 0.7618
# Epoch 16/20 | Train Loss: 0.0245 Acc: 0.9939 | Val Loss: 1.6637 Acc: 0.7857
# Epoch 17/20 | Train Loss: 0.0011 Acc: 0.9999 | Val Loss: 1.9565 Acc: 0.7804
# Epoch 18/20 | Train Loss: 0.0012 Acc: 0.9998 | Val Loss: 2.2935 Acc: 0.7653
# Epoch 19/20 | Train Loss: 0.0052 Acc: 0.9990 | Val Loss: 2.6358 Acc: 0.7613
# Epoch 20/20 | Train Loss: 0.0016 Acc: 0.9998 | Val Loss: 2.2798 Acc: 0.7638
# ✓ Finished S14. Accuracy: 76.38%
# DEBUG: Model initialized with flattened_size = 11520
# Epoch 1/20 | Train Loss: 0.3431 Acc: 0.8429 | Val Loss: 0.3625 Acc: 0.8175
# Epoch 2/20 | Train Loss: 0.1707 Acc: 0.9361 | Val Loss: 0.2633 Acc: 0.8754
# Epoch 3/20 | Train Loss: 0.0852 Acc: 0.9728 | Val Loss: 0.2117 Acc: 0.9041
# Epoch 4/20 | Train Loss: 0.0449 Acc: 0.9880 | Val Loss: 0.1704 Acc: 0.9246
# Epoch 5/20 | Train Loss: 0.0207 Acc: 0.9953 | Val Loss: 0.1691 Acc: 0.9343
# Epoch 6/20 | Train Loss: 0.0161 Acc: 0.9964 | Val Loss: 0.1806 Acc: 0.9275
# Epoch 7/20 | Train Loss: 0.0106 Acc: 0.9976 | Val Loss: 0.1350 Acc: 0.9455
# Epoch 8/20 | Train Loss: 0.0117 Acc: 0.9972 | Val Loss: 0.1212 Acc: 0.9494
# Epoch 9/20 | Train Loss: 0.0036 Acc: 0.9997 | Val Loss: 0.1590 Acc: 0.9411
# Epoch 10/20 | Train Loss: 0.0089 Acc: 0.9975 | Val Loss: 0.1443 Acc: 0.9382
# Epoch 11/20 | Train Loss: 0.0051 Acc: 0.9988 | Val Loss: 0.1639 Acc: 0.9353
# Epoch 12/20 | Train Loss: 0.0020 Acc: 0.9997 | Val Loss: 0.1764 Acc: 0.9387
# Epoch 13/20 | Train Loss: 0.0088 Acc: 0.9981 | Val Loss: 0.2012 Acc: 0.9377
# Epoch 14/20 | Train Loss: 0.0069 Acc: 0.9985 | Val Loss: 0.1679 Acc: 0.9173
# Epoch 15/20 | Train Loss: 0.0011 Acc: 1.0000 | Val Loss: 0.2698 Acc: 0.9314
# Epoch 16/20 | Train Loss: 0.0007 Acc: 1.0000 | Val Loss: 0.4256 Acc: 0.8745
# Epoch 17/20 | Train Loss: 0.0047 Acc: 0.9987 | Val Loss: 0.2648 Acc: 0.9255
# Epoch 18/20 | Train Loss: 0.0046 Acc: 0.9988 | Val Loss: 0.1265 Acc: 0.9533
# Epoch 19/20 | Train Loss: 0.0007 Acc: 1.0000 | Val Loss: 0.2056 Acc: 0.9367
# Epoch 20/20 | Train Loss: 0.0076 Acc: 0.9982 | Val Loss: 0.2371 Acc: 0.9241
# ✓ Finished S15. Accuracy: 92.41%
# DEBUG: Model initialized with flattened_size = 11520
# Epoch 1/20 | Train Loss: 0.3622 Acc: 0.8273 | Val Loss: 0.0935 Acc: 1.0000
# Epoch 2/20 | Train Loss: 0.1811 Acc: 0.9253 | Val Loss: 0.0449 Acc: 1.0000
# Epoch 3/20 | Train Loss: 0.0933 Acc: 0.9696 | Val Loss: 0.0145 Acc: 1.0000
# Epoch 4/20 | Train Loss: 0.0501 Acc: 0.9869 | Val Loss: 0.0146 Acc: 1.0000
# Epoch 5/20 | Train Loss: 0.0405 Acc: 0.9884 | Val Loss: 0.0058 Acc: 1.0000
# Epoch 6/20 | Train Loss: 0.0184 Acc: 0.9962 | Val Loss: 0.0044 Acc: 1.0000
# Epoch 7/20 | Train Loss: 0.0194 Acc: 0.9946 | Val Loss: 0.0029 Acc: 1.0000
# Epoch 8/20 | Train Loss: 0.0195 Acc: 0.9950 | Val Loss: 0.0073 Acc: 1.0000
# Epoch 9/20 | Train Loss: 0.0081 Acc: 0.9986 | Val Loss: 0.0017 Acc: 1.0000
# Epoch 10/20 | Train Loss: 0.0031 Acc: 0.9998 | Val Loss: 0.0003 Acc: 1.0000
# Epoch 11/20 | Train Loss: 0.0113 Acc: 0.9969 | Val Loss: 0.0003 Acc: 1.0000
# Epoch 12/20 | Train Loss: 0.0029 Acc: 0.9996 | Val Loss: 0.0018 Acc: 1.0000
# Epoch 13/20 | Train Loss: 0.0068 Acc: 0.9983 | Val Loss: 0.0002 Acc: 1.0000
# Epoch 14/20 | Train Loss: 0.0017 Acc: 0.9999 | Val Loss: 0.0009 Acc: 1.0000
# Epoch 15/20 | Train Loss: 0.0058 Acc: 0.9986 | Val Loss: 0.0003 Acc: 1.0000
# Epoch 16/20 | Train Loss: 0.0016 Acc: 0.9998 | Val Loss: 0.0023 Acc: 0.9995
# Epoch 17/20 | Train Loss: 0.0008 Acc: 0.9999 | Val Loss: 0.0001 Acc: 1.0000
# Epoch 18/20 | Train Loss: 0.0072 Acc: 0.9982 | Val Loss: 0.0000 Acc: 1.0000
# Epoch 19/20 | Train Loss: 0.0007 Acc: 1.0000 | Val Loss: 0.0000 Acc: 1.0000
# Epoch 20/20 | Train Loss: 0.0008 Acc: 0.9999 | Val Loss: 0.0000 Acc: 1.0000
# ✓ Finished S16. Accuracy: 100.00%
# DEBUG: Model initialized with flattened_size = 11520
# Epoch 1/20 | Train Loss: 0.3240 Acc: 0.8512 | Val Loss: 0.1429 Acc: 0.9533
# Epoch 2/20 | Train Loss: 0.1342 Acc: 0.9518 | Val Loss: 0.0962 Acc: 0.9638
# Epoch 3/20 | Train Loss: 0.0630 Acc: 0.9809 | Val Loss: 0.1227 Acc: 0.9418
# Epoch 4/20 | Train Loss: 0.0265 Acc: 0.9933 | Val Loss: 0.1736 Acc: 0.9233
# Epoch 5/20 | Train Loss: 0.0134 Acc: 0.9972 | Val Loss: 0.2372 Acc: 0.8928
# Epoch 6/20 | Train Loss: 0.0209 Acc: 0.9949 | Val Loss: 0.2033 Acc: 0.9128
# Epoch 7/20 | Train Loss: 0.0050 Acc: 0.9992 | Val Loss: 0.2528 Acc: 0.9161
# Epoch 8/20 | Train Loss: 0.0043 Acc: 0.9993 | Val Loss: 0.3432 Acc: 0.8742
# Epoch 9/20 | Train Loss: 0.0108 Acc: 0.9981 | Val Loss: 0.1280 Acc: 0.9438
# Epoch 10/20 | Train Loss: 0.0072 Acc: 0.9981 | Val Loss: 0.3006 Acc: 0.8923
# Epoch 11/20 | Train Loss: 0.0014 Acc: 0.9999 | Val Loss: 0.1464 Acc: 0.9561
# Epoch 12/20 | Train Loss: 0.0032 Acc: 0.9995 | Val Loss: 0.1140 Acc: 0.9628
# Epoch 13/20 | Train Loss: 0.0007 Acc: 1.0000 | Val Loss: 0.1621 Acc: 0.9500
# Epoch 14/20 | Train Loss: 0.0006 Acc: 1.0000 | Val Loss: 0.2793 Acc: 0.9223
# Epoch 15/20 | Train Loss: 0.0051 Acc: 0.9989 | Val Loss: 0.2026 Acc: 0.9352
# Epoch 16/20 | Train Loss: 0.0111 Acc: 0.9978 | Val Loss: 0.0945 Acc: 0.9609
# Epoch 17/20 | Train Loss: 0.0010 Acc: 0.9998 | Val Loss: 0.1659 Acc: 0.9409
# Epoch 18/20 | Train Loss: 0.0006 Acc: 0.9999 | Val Loss: 0.1143 Acc: 0.9662
# Epoch 19/20 | Train Loss: 0.0042 Acc: 0.9988 | Val Loss: 0.1512 Acc: 0.9504
# Epoch 20/20 | Train Loss: 0.0076 Acc: 0.9976 | Val Loss: 0.2279 Acc: 0.9309
# ✓ Finished S17. Accuracy: 93.09%

# %%
import numpy as np

#Extract final accuracy from each LOSO fold (each test subject)
accuracies = [data['final_accuracy'] for data in all_loso_results.values()]

#Compute overall performance statistics
mean_acc = np.mean(accuracies)
std_acc = np.std(accuracies)

#Report LOSO performance
print(f"Mean LOSO Accuracy: {mean_acc*100:.2f}%")
print(f"Standard Deviation: {std_acc*100:.2f}%")
# Out:
# Mean LOSO Accuracy: 84.13%
# Standard Deviation: 14.10%
